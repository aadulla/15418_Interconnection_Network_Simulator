# %%
import os
import matplotlib.pyplot as plt

from src.data_visualizer import *

# %%
path1 = 'test_suite/routing_+_flow_control_+_message_size_+_message_distribution/'

# %%
path2 = 'test_suite/routing_+_buffer_capacity_+_virtual_channel_+_granularity/'

# %%
test_msg_0 = [ 
             path1+'test_0', # SF + packet
             path1+'test_4', # SF + flit 
             path1+'test_8', # CT + packet
             path1+'test_12', # CT + flit
             ]
test_msg_1 = [ 
             path1+'test_1', # SF + packet
             path1+'test_5', # SF + flit 
             path1+'test_9', # CT + packet
             path1+'test_13', # CT + flit
             ]
test_msg_2 = [ 
             path1+'test_2', # SF + packet
             path1+'test_6', # SF + flit 
             path1+'test_10', # CT + packet
             path1+'test_14', # CT + flit
             ]
test_msg_3 = [ 
             path1+'test_3', # SF + packet
             path1+'test_7', # SF + flit 
             path1+'test_11', # CT + packet
             path1+'test_15', # CT + flit
             ]

global_stats_df_dict_0 = data_parser(test_msg_0)
global_stats_df_dict_1 = data_parser(test_msg_1)
global_stats_df_dict_2 = data_parser(test_msg_2)
global_stats_df_dict_3 = data_parser(test_msg_3)

global_stats_df_dict_lst = [global_stats_df_dict_0, global_stats_df_dict_1, global_stats_df_dict_2, global_stats_df_dict_3]

titles = [
            'Routing: Mesh XY, Message Size: 10, Number of Messages: 5000',
            'Routing: Mesh XY, Message Size: 50, Number of Messages: 1000',
            'Routing: Mesh XY, Message Size: 100, Number of Messages: 500',
            'Routing: Mesh XY, Message Size: 500, Number of Messages: 100',
         ]

legend = ["SF + Packet", "SF + Flit", "CT + Packet", "CT + Flit"]

# %%
disp_aggregate_stats(global_stats_df_dict_lst, legend)
# Out:
#             SF + Packet   SF + Flit  CT + Packet   CT + Flit
# latency      255.003000  403.078000   186.047000  295.933000
# distance       8.650900    8.650900     8.650900    8.650900
# size          10.000000   10.000000    10.000000   10.000000
# throughput     0.645661    1.124350     0.768285    1.176470
# speed          0.033925    0.021462     0.046498    0.029233
#
#             SF + Packet   SF + Flit  CT + Packet   CT + Flit
# latency      619.060000  795.623000   556.946000  671.494000
# distance       8.652900    8.652900     8.652900    8.652900
# size          50.000000   50.000000    50.000000   50.000000
# throughput     0.107308    0.168976     0.120555    0.184775
# speed          0.013978    0.010876     0.015536    0.012886
#
#             SF + Packet    SF + Flit  CT + Packet    CT + Flit
# latency     1126.420000  1152.160000  1052.720000  1021.710000
# distance       8.587000     8.587000     8.587000     8.587000
# size         100.000000   100.000000   100.000000   100.000000
# throughput     0.051632     0.082919     0.050906     0.089063
# speed          0.007623     0.007453     0.008157     0.008405
#
#             SF + Packet    SF + Flit  CT + Packet    CT + Flit
# latency     4062.310000  3908.480000  3994.650000  3803.830000
# distance       9.152300     9.152300     9.152300     9.152300
# size         500.000000   500.000000   500.000000   500.000000
# throughput     0.010378     0.011998     0.010462     0.012344
# speed          0.002253     0.002342     0.002291     0.002406

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'tx',
                    "Clock Cycle", 
                    "Number of Flits Transmitted", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Flit Transmission Time Series Plot", fontsize=28)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'rx',
                    "Clock Cycle", 
                    "Number of Flits Received", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Flit Reception Time Series Plot", fontsize=28)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'stalls',
                    "Clock Cycle", 
                    "Number of Contentions", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Contentions Time-Series Plot")
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'buffers',
                    "Clock Cycle", 
                    "Buffer Efficiency", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Buffer Efficiency Time-Series Plot", fontsize=28)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
kde_subplot(ax, 
            global_stats_df_dict_lst, 
            'latency',
            "Message Latency in Clock Cycles", 
            "Normalized Frequency", 
            titles, 
            legend, 
            0,
            2000, 
            0.03)
fig.set_size_inches(15, 11)
fig.suptitle("Message Latency Distribution KDE Plot", fontsize=28)
plt.show()
