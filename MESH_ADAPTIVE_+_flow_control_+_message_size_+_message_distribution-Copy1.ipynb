# %%
import os
import matplotlib.pyplot as plt

from src.data_visualizer import *

# %%
path1 = 'test_suite/routing_+_flow_control_+_message_size_+_message_distribution/'

# %%
path2 = 'test_suite/routing_+_buffer_capacity_+_virtual_channel_+_granularity/'

# %%
test_msg_0 = [ 
             path1+'test_16', # SF + packet
             path1+'test_20', # SF + flit 
             path1+'test_24', # CT + packet
             path1+'test_28', # CT + flit
             ]
test_msg_1 = [ 
             path1+'test_17', # SF + packet
             path1+'test_21', # SF + flit 
             path1+'test_25', # CT + packet
             path1+'test_29', # CT + flit
             ]
test_msg_2 = [ 
             path1+'test_18', # SF + packet
             path1+'test_22', # SF + flit 
             path1+'test_26', # CT + packet
             path1+'test_30', # CT + flit
             ]
test_msg_3 = [ 
             path1+'test_19', # SF + packet
             path1+'test_23', # SF + flit 
             path1+'test_27', # CT + packet
             path1+'test_31', # CT + flit
             ]

global_stats_df_dict_0 = data_parser(test_msg_0)
global_stats_df_dict_1 = data_parser(test_msg_1)
global_stats_df_dict_2 = data_parser(test_msg_2)
global_stats_df_dict_3 = data_parser(test_msg_3)

global_stats_df_dict_lst = [global_stats_df_dict_0, global_stats_df_dict_1, global_stats_df_dict_2, global_stats_df_dict_3]

titles = [
            'Routing: Mesh Adaptive, Message Size: 10, Number of Messages: 5000',
            'Routing: Mesh Adaptive, Message Size: 50, Number of Messages: 1000',
            'Routing: Mesh Adaptive, Message Size: 100, Number of Messages: 500',
            'Routing: Mesh Adaptive, Message Size: 500, Number of Messages: 100',
         ]

legend = ["SF + Packet", "SF + Flit", "CT + Packet", "CT + Flit"]

# %%
disp_aggregate_stats(global_stats_df_dict_lst, legend)
# Out:
#             SF + Packet   SF + Flit  CT + Packet   CT + Flit
# latency      257.707000  465.956000   188.145000  382.788000
# distance       8.650900    8.650900     8.650900    8.650900
# size          10.000000   10.000000    10.000000   10.000000
# throughput     0.669792    0.924556     0.682967    0.821423
# speed          0.033569    0.018566     0.045980    0.022600
#
#             SF + Packet   SF + Flit  CT + Packet   CT + Flit
# latency      630.105000  912.923000   569.978000  931.051000
# distance       8.652900    8.652900     8.652900    8.652900
# size          50.000000   50.000000    50.000000   50.000000
# throughput     0.105463    0.174216     0.108956    0.148743
# speed          0.013732    0.009478     0.015181    0.009294
#
#             SF + Packet    SF + Flit  CT + Packet    CT + Flit
# latency     1131.580000  1339.770000  1053.470000  1291.970000
# distance       8.587000     8.587000     8.587000     8.587000
# size         100.000000   100.000000   100.000000   100.000000
# throughput     0.050571     0.084746     0.050963     0.081766
# speed          0.007588     0.006409     0.008151     0.006646
#
#             SF + Packet    SF + Flit  CT + Packet    CT + Flit
# latency     4062.310000  3977.830000  3994.650000  4154.740000
# distance       9.152300     9.152300     9.152300     9.152300
# size         500.000000   500.000000   500.000000   500.000000
# throughput     0.010378     0.014972     0.010462     0.013620
# speed          0.002253     0.002301     0.002291     0.002203

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'tx',
                    "Clock Cycle", 
                    "Number of Flits Transmitted", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Flit Transmission Time Series Plot", fontsize=28)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'rx',
                    "Clock Cycle", 
                    "Number of Flits Received", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Flit Reception Time Series Plot")
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'stalls',
                    "Clock Cycle", 
                    "Number of Contentions", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Contentions Time-Series Plot")
plt.show()

# %%
fig, ax = plt.subplots(2,2)
time_series_subplot(ax, 
                    global_stats_df_dict_lst, 
                    'buffers',
                    "Clock Cycle", 
                    "Buffer Efficiency", 
                    titles, 
                    legend, 
                    200)
fig.set_size_inches(15, 11)
fig.suptitle("Buffer Efficiency Time-Series Plot", fontsize=28)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
kde_subplot(ax, 
            global_stats_df_dict_lst, 
            'latency',
            "Message Latency in Clock Cycles", 
            "Normalized Frequency", 
            titles, 
            legend, 
            0,
            2000, 
            0.05)
fig.set_size_inches(15, 11)
fig.suptitle("Message Latency Distribution KDE Plot")
plt.show()
